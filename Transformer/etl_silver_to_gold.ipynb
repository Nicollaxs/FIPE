# %% [markdown]
# # ETL Silver to Gold
# Transformacoes analiticas e carga para camada gold.

# %%
import pandas as pd

silver_path = '../Data Layer/silver/silver_fipe.parquet'
# df_silver = pd.read_parquet(silver_path)
# df_gold = ...
# df_gold.to_parquet('../Data Layer/gold/gold_fipe.parquet', index=False)
